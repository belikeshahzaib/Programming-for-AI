# %%
import numpy, json, requests

# %%
with open('api.text', 'r') as APIFILE:
    url = APIFILE.read()
    print(url)
# Out:
# https://api.cricapi.com/v1/matches?apikey=799ab58a-e988-4ed1-b0f0-c464b5f646df&offset=0

# %%
try:
    response = requests.get(url)
except requests.exceptions.RequestException as e:
    print(f"Error occured: {str(e)}")

# %%
print(response.status_code)
# Out:
# 200

# %%
if response.status_code != 200:
    print(f"Http error: {response.status_code}, text: {response.text}")

# %%
res = response.json()

# %%
#API INFO METADATA

info = res.get("info", [])
statusOFAPI = res.get('status')
print(f"Api Info: {info}")
print(f"Status: {statusOFAPI}")
# Out:
# Api Info: {'hitsToday': 1, 'hitsUsed': 1, 'hitsLimit': 100, 'credits': 0, 'server': 8, 'offsetRows': 0, 'totalRows': 13196, 'queryTime': 282.4594, 's': 0, 'cache': 0}
# Status: success

# %%
if res.get('status') != "success":
    error = res.get('reason')
    print(f"Error: {error}")
elif "data" not in res:
    print(f"No Data available for match")
else:
    print("Match data available")
# Out:
# Match data available

# %%
content = res.get("data", [])
for matches in content:
    print("---------------------------------")
    print(f"Match name: {matches.get("name")}")
    print(f"Match Status: {matches.get("status")}")
    print(f"Venue: {matches.get("venue")}")
    print(f"Date: {matches.get("date")}")
    if "score" in matches:
        score = matches.get("score", [])
        for s in score:
            print("    ----------------------------")
            print(f"    Inning : {s.get('inning')}")
            print(f"    Runs: {s.get('r')}")
            print(f"    Wickets: {s.get('w')}")
            print(f"    Overs: {s.get('o')}")
# Out:
# ---------------------------------
# Match name: Nepal vs United States of America, 86th Match
# Match Status: United States of America won by 106 runs
# Venue: Dubai International Cricket Stadium, Dubai
# Date: 2025-10-26
#     ----------------------------
#     Inning : United States of America Inning 1
#     Runs: 262
#     Wickets: 6
#     Overs: 50
#     ----------------------------
#     Inning : Nepal Inning 1
#     Runs: 156
#     Wickets: 10
#     Overs: 39.1
# ---------------------------------
# Match name: Brazil vs Mexico, 3rd Match
# Match Status: Mexico won by 54 runs
# Venue: Sao Fernando Polo and Cricket Club, Seropedica
# Date: 2025-11-01
#     ----------------------------
#     Inning : Mexico Inning 1
#     Runs: 179
#     Wickets: 5
#     Overs: 20
#     ----------------------------
#     Inning : Brazil Inning 1
#     Runs: 125
#     Wickets: 9
#     Overs: 19.5
# ---------------------------------
# Match name: Brazil vs Panama, 2nd Match
# Match Status: No result
# Venue: Sao Fernando Polo and Cricket Club, Seropedica
# Date: 2025-10-31
#     ----------------------------
#     Inning : Brazil Inning 1
#     Runs: 92
#     Wickets: 10
#     Overs: 17
# ---------------------------------
# Match name: Panama vs Mexico, 1st Match
# Match Status: No result (due to rain)
# Venue: Sao Fernando Polo and Cricket Club, Seropedica
# Date: 2025-10-30
#     ----------------------------
#     Inning : Panama Inning 1
#     Runs: 40
#     Wickets: 6
#     Overs: 8
# ---------------------------------
# Match name: Thailand Women vs Papua New Guinea Women, 6th Match
# Match Status: Match starts at Nov 17, 06:30 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-17
# ---------------------------------
# Match name: Scotland Women vs Namibia Women, 5th Match
# Match Status: Match starts at Nov 17, 02:00 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-17
# ---------------------------------
# Match name: Thailand Women vs Scotland Women, 4th Match
# Match Status: Match starts at Nov 15, 06:30 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-15
# ---------------------------------
# Match name: Namibia Women vs Papua New Guinea Women, 3rd Match
# Match Status: Match starts at Nov 15, 02:00 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-15
# ---------------------------------
# Match name: Thailand Women vs Namibia Women, 2nd Match
# Match Status: Match starts at Nov 14, 06:30 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-14
# ---------------------------------
# Match name: Scotland Women vs Papua New Guinea Women, 1st Match
# Match Status: Match starts at Nov 14, 02:00 GMT
# Venue: Terdthai Cricket Ground, Bangkok
# Date: 2025-11-14
# ---------------------------------
# Match name: Papua New Guinea Women vs United Arab Emirates Women, 4th ODI
# Match Status: Papua New Guinea Women won by 78 runs
# Venue: Amini Park, Port Moresby
# Date: 2025-10-19
#     ----------------------------
#     Inning : Papua New Guinea Women Inning 1
#     Runs: 210
#     Wickets: 9
#     Overs: 50
#     ----------------------------
#     Inning : United Arab Emirates Women Inning 1
#     Runs: 132
#     Wickets: 10
#     Overs: 42.4
# ---------------------------------
# Match name: Uganda Women vs Canada Women, 5th T20I
# Match Status: Uganda Women won by 12 runs
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-26
#     ----------------------------
#     Inning : Uganda Women Inning 1
#     Runs: 101
#     Wickets: 4
#     Overs: 20
#     ----------------------------
#     Inning : Canada Women Inning 1
#     Runs: 89
#     Wickets: 10
#     Overs: 20
# ---------------------------------
# Match name: Uganda Women vs Canada Women, 4th T20I
# Match Status: Uganda Women won by 43 runs
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-24
#     ----------------------------
#     Inning : uganda women Inning 1
#     Runs: 113
#     Wickets: 4
#     Overs: 20
#     ----------------------------
#     Inning : Uganda Women,Canada Women Inning 1
#     Runs: 70
#     Wickets: 9
#     Overs: 20
# ---------------------------------
# Match name: Romania vs Austria, 4th T20I
# Match Status: Austria won by 42 runs
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-19
#     ----------------------------
#     Inning : Austria Inning 1
#     Runs: 207
#     Wickets: 6
#     Overs: 20
#     ----------------------------
#     Inning : Romania Inning 1
#     Runs: 165
#     Wickets: 10
#     Overs: 18.5
# ---------------------------------
# Match name: Romania vs Austria, 3rd T20I
# Match Status: Austria won by 7 wkts
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-19
#     ----------------------------
#     Inning : Romania Inning 1
#     Runs: 157
#     Wickets: 10
#     Overs: 20
#     ----------------------------
#     Inning : Austria Inning 1
#     Runs: 163
#     Wickets: 3
#     Overs: 16
# ---------------------------------
# Match name: Papua New Guinea Women vs United Arab Emirates Women, 3rd ODI
# Match Status: United Arab Emirates Women won by 160 runs
# Venue: Amini Park, Port Moresby
# Date: 2025-10-17
#     ----------------------------
#     Inning : United Arab Emirates Women Inning 1
#     Runs: 193
#     Wickets: 7
#     Overs: 50
#     ----------------------------
#     Inning : Papua New Guinea Women Inning 1
#     Runs: 33
#     Wickets: 10
#     Overs: 15.4
# ---------------------------------
# Match name: Uganda Women vs Canada Women, 3rd T20I
# Match Status: Uganda Women won by 18 runs
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-23
#     ----------------------------
#     Inning : Uganda Women Inning 1
#     Runs: 100
#     Wickets: 6
#     Overs: 20
#     ----------------------------
#     Inning : Canada Women Inning 1
#     Runs: 82
#     Wickets: 10
#     Overs: 18.3
# ---------------------------------
# Match name: Uganda Women vs Canada Women, 2nd T20I
# Match Status: Uganda Women won by 4 wkts
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-21
#     ----------------------------
#     Inning : Canada Women Inning 1
#     Runs: 82
#     Wickets: 6
#     Overs: 20
#     ----------------------------
#     Inning : Uganda Women Inning 1
#     Runs: 83
#     Wickets: 6
#     Overs: 19
# ---------------------------------
# Match name: Uganda Women vs Canada Women, 1st T20I
# Match Status: Uganda Women won by 7 wkts
# Venue: Lugogo Stadium, Kampala
# Date: 2025-10-20
#     ----------------------------
#     Inning : Canada Women Inning 1
#     Runs: 67
#     Wickets: 10
#     Overs: 19
#     ----------------------------
#     Inning : Uganda Women Inning 1
#     Runs: 68
#     Wickets: 3
#     Overs: 12
# ---------------------------------
# Match name: Papua New Guinea Women vs United Arab Emirates Women, 2nd ODI
# Match Status: Papua New Guinea Women won by 3 wkts
# Venue: Amini Park, Port Moresby
# Date: 2025-10-15
#     ----------------------------
#     Inning : United Arab Emirates Women Inning 1
#     Runs: 143
#     Wickets: 10
#     Overs: 45.4
#     ----------------------------
#     Inning : Papua New Guinea Women Inning 1
#     Runs: 146
#     Wickets: 7
#     Overs: 42.5
# ---------------------------------
# Match name: Papua New Guinea Women vs United Arab Emirates Women, 1st ODI
# Match Status: United Arab Emirates Women won by 5 wkts
# Venue: Amini Park, Port Moresby
# Date: 2025-10-12
#     ----------------------------
#     Inning : Papua New Guinea Women Inning 1
#     Runs: 93
#     Wickets: 10
#     Overs: 33.2
#     ----------------------------
#     Inning : United Arab Emirates Women Inning 1
#     Runs: 97
#     Wickets: 5
#     Overs: 33.1
# ---------------------------------
# Match name: Romania vs Austria, 2nd T20I
# Match Status: Romania won by 3 wkts
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-18
#     ----------------------------
#     Inning : Austria Inning 1
#     Runs: 171
#     Wickets: 10
#     Overs: 19.2
#     ----------------------------
#     Inning : Romania Inning 1
#     Runs: 172
#     Wickets: 7
#     Overs: 19.2
# ---------------------------------
# Match name: Romania vs Austria, 1st T20I
# Match Status: Austria won by 4 wkts
# Venue: Moara Vlasiei Cricket Ground, Ilfov County
# Date: 2025-10-18
#     ----------------------------
#     Inning : Romania Inning 1
#     Runs: 173
#     Wickets: 9
#     Overs: 20
#     ----------------------------
#     Inning : Austria Inning 1
#     Runs: 177
#     Wickets: 6
#     Overs: 19
# ---------------------------------
# Match name: Pakistan vs South Africa, 3rd ODI
# Match Status: Match starts at Nov 08, 09:00 GMT
# Venue: Iqbal Stadium, Faisalabad
# Date: 2025-11-08
# ---------------------------------
# Match name: Pakistan vs South Africa, 2nd ODI
# Match Status: Match starts at Nov 06, 10:00 GMT
# Venue: Iqbal Stadium, Faisalabad
# Date: 2025-11-06
